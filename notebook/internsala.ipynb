# %%
import pandas as pd

# %%
df = pd.read_csv('../internshala_ai_internships.csv')

# %%
df
# Out:
#                                         title  \
# 0                          Prompt Engineering
# 1                      AI Business Automation
# 2                            Machine Learning
# 3                                Data Science
# 4    Gen AI Artist – Concept Art & Filmmaking
# ..                                        ...
# 117                              Data Science
# 118                  Robotics Data Collection
# 119       AI Product Development - Full Stack
# 120                          Robotics Trainer
# 121                            Product & Tech
#
#                                      company  \
# 0                 Gateway Software Solutions
# 1    Stanza Shipping (India) Private Limited
# 2                 Gateway Software Solutions
# 3                 Gateway Software Solutions
# 4                                       AVGC
# ..                                       ...
# 117                                  Nexaora
# ...

# %%
df.shape
# Out:
# (122, 6)
